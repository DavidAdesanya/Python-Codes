# %%
#Importing the necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
#Reading the file
Chainlink=pd.read_csv(r'/Users/davidadesanya/Downloads/Cryptocurrency Historical Prices/coin_ChainLink.csv', index_col = 'Date', parse_dates=True)

# %%
#Viewing a sample of the data
Chainlink.head()
# Out:
#                      SNo       Name Symbol      High       Low      Open  \
# Date
# 2017-09-21 23:59:59    1  Chainlink   LINK  0.207892  0.155292  0.189132
# 2017-09-22 23:59:59    2  Chainlink   LINK  0.181675  0.139869  0.169826
# 2017-09-23 23:59:59    3  Chainlink   LINK  0.157440  0.126297  0.149562
# 2017-09-24 23:59:59    4  Chainlink   LINK  0.190250  0.130275  0.131110
# 2017-09-25 23:59:59    5  Chainlink   LINK  0.182637  0.158580  0.170636
#
#                         Close     Volume   Marketcap
# Date
# 2017-09-21 23:59:59  0.169680  2126270.0  59388000.0
# 2017-09-22 23:59:59  0.150503  1423220.0  52676050.0
# 2017-09-23 23:59:59  0.131129  1186670.0  45895150.0
# 2017-09-24 23:59:59  0.170278  1025740.0  59597300.0
# 2017-09-25 23:59:59  0.182198  1021370.0  63769300.0

# %%
#Checking the properties of each column
Chainlink.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1385 entries, 2017-09-21 23:59:59 to 2021-07-06 23:59:59
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   SNo        1385 non-null   int64
#  1   Name       1385 non-null   object
#  2   Symbol     1385 non-null   object
#  3   High       1385 non-null   float64
#  4   Low        1385 non-null   float64
#  5   Open       1385 non-null   float64
#  6   Close      1385 non-null   float64
#  7   Volume     1385 non-null   float64
#  8   Marketcap  1385 non-null   float64
# dtypes: float64(6), int64(1), object(2)
# memory usage: 108.2+ KB

# %%
Chainlink.shape
# Out:
# (1385, 9)

# %%
#Dropping unnecessary columns
Chainlink.drop(['SNo','Name','Symbol'], axis='columns',inplace=True)

# %%
#Viewing a sample of the data again after the changes have been made
Chainlink.head()
# Out:
#                          High       Low      Open     Close     Volume  \
# Date
# 2017-09-21 23:59:59  0.207892  0.155292  0.189132  0.169680  2126270.0
# 2017-09-22 23:59:59  0.181675  0.139869  0.169826  0.150503  1423220.0
# 2017-09-23 23:59:59  0.157440  0.126297  0.149562  0.131129  1186670.0
# 2017-09-24 23:59:59  0.190250  0.130275  0.131110  0.170278  1025740.0
# 2017-09-25 23:59:59  0.182637  0.158580  0.170636  0.182198  1021370.0
#
#                       Marketcap
# Date
# 2017-09-21 23:59:59  59388000.0
# 2017-09-22 23:59:59  52676050.0
# 2017-09-23 23:59:59  45895150.0
# 2017-09-24 23:59:59  59597300.0
# 2017-09-25 23:59:59  63769300.0

# %%
#Another way to check for null values besides the .info() function
Chainlink.isna().sum()
# Out:
# High         0
# Low          0
# Open         0
# Close        0
# Volume       0
# Marketcap    0
# dtype: int64

# %%
import mplfinance as mpl

# %%
#Historical price chart from 2017
mpl.plot(Chainlink, type='line', style='yahoo', figratio=(30,11))

# %%
#Price chart for 2018(This is a sample. Could be any year between '17 and '21)
mpl.plot(Chainlink.loc['2018-01-01':'2018-12-31'], type='candle', style='yahoo', figratio=(30,11))
